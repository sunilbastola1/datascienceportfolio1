# %% [markdown]
# ## Analysis of a car sell record Dataset
#
# We have been provided with a car sell record dataset. In this dataset, we have thounds of car sell records.
#
# The structure of this dataset is represented in the header shown below.
#
# name
# year
# selling_price
# km_driven
# fuel
# seller_type
# transmission
# Owner
#
# | name | year | selling_price | km_driven| fuel | seller_type | transmission | Owner |
#
#     | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
#
# #### Description of Fields
#
# * __name__ - detail car type of the sold car
# * __year__ - Year of the car when it was bought
# * __selling_price__ - Price at which the car is being sold
# * __km_driven__ - Number of Kilometres the car is driven
# * __fuel__ - Fuel type of car (petrol / diesel / CNG / LPG / electric)
# * __seller_type__ - Tells if a Seller is Individual or a Dealer
# * __transmission__ - Gear transmission of the car (Automatic/Manual)
# * __owner__ - Number of previous owners of the car.
#
# There are four questions to explore with the data as shown below.

# %%
your_name = "Sunil Bastola"
your_student_id = "48659851"

# %%
# libraries you might need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# if you are using google colab with google drive, you could read files from google drive with the following codes
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
#  ## Q1. Remove missing data
#
# Please remove the records that match ANY of the below two conditions in the csv file:
#
#  * year is missing
#  * fuel is 'none'
#
# __Display the DataFrame, counting number of Null values in each column, and print the length of the data__ before and after removing the missing data.

# %%
#Read the CSV value from the dataset and display the dataframe
car_data = pd.read_csv('car_sell.csv')
car_data
# Out:
#       Unnamed: 0                                 name    year  selling_price  \
# 0              0                        Maruti 800 AC  2007.0          60000
# 1              1             Maruti Wagon R LXI Minor  2007.0         135000
# 2              2                 Hyundai Verna 1.6 SX  2012.0         600000
# 3              3               Datsun RediGO T Option  2017.0         250000
# 4              4                Honda Amaze VX i-DTEC  2014.0         450000
# ...          ...                                  ...     ...            ...
# 4335        4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0         409999
# 4336        4336           Hyundai i20 Magna 1.4 CRDi  2014.0         409999
# 4337        4337                  Maruti 800 AC BSIII  2009.0         110000
# 4338        4338     Hyundai Creta 1.6 CRDi SX Option  2016.0         865000
# 4339        4339                     Renault KWID RXT  2016.0         225000
#
# ...

# %%
#Print the total number of rows or length in the data..
print("The length of data is:", len(car_data))
# Out:
# The length of data is: 4340

# %%
#Counting the null values in each column
car_data.isnull().sum()
# Out:
# Unnamed: 0         0
# name               0
# year             310
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# dtype: int64

# %%
#Checking the missing values of 'year' column in the dataframe.
car_data[car_data['year'].isnull()]
# Out:
#       Unnamed: 0                                     name  year  \
# 32            32                          Audi Q5 2.0 TDI   NaN
# 33            33                          Honda City V MT   NaN
# 61            61                 Mahindra Jeep CL 500 MDI   NaN
# 66            66                          Toyota Etios GD   NaN
# 83            83                        Nissan Terrano XL   NaN
# ...          ...                                      ...   ...
# 4263        4263                             Honda Jazz S   NaN
# 4276        4276              Ford Fiesta 1.6 ZXi Duratec   NaN
# 4283        4283                 Maruti Wagon R LXI BS IV   NaN
# 4300        4300  Mercedes-Benz E-Class E250 CDI Elegance   NaN
# 4319        4319                         Maruti Swift LDI   NaN
#
#       selling_price  km_driven    fuel seller_type transmission         owner
# 32          1190000     175900  Diesel      Dealer    Automatic   First Owner
# ...

# %%
#Remove the NaN values in the 'year' column...
car_data_1 = car_data.dropna(subset = 'year')
car_data_1
# Out:
#       Unnamed: 0                                 name    year  selling_price  \
# 0              0                        Maruti 800 AC  2007.0          60000
# 1              1             Maruti Wagon R LXI Minor  2007.0         135000
# 2              2                 Hyundai Verna 1.6 SX  2012.0         600000
# 3              3               Datsun RediGO T Option  2017.0         250000
# 4              4                Honda Amaze VX i-DTEC  2014.0         450000
# ...          ...                                  ...     ...            ...
# 4335        4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0         409999
# 4336        4336           Hyundai i20 Magna 1.4 CRDi  2014.0         409999
# 4337        4337                  Maruti 800 AC BSIII  2009.0         110000
# 4338        4338     Hyundai Creta 1.6 CRDi SX Option  2016.0         865000
# 4339        4339                     Renault KWID RXT  2016.0         225000
#
# ...

# %%
#See within the fuel column where the values are "none" 
car_data_1[car_data_1['fuel'] == 'none']
# Out:
#       Unnamed: 0                                         name    year  \
# 5              5                         Maruti Alto LX BSIII  2007.0
# 21            21                     Hyundai Creta 1.6 VTVT S  2015.0
# 46            46                    Mahindra Scorpio 1.99 S10  2014.0
# 177          177                          Maruti 800 Std BSII  2004.0
# 307          307    Hyundai Grand i10 1.2 Kappa Sportz Option  2013.0
# ...          ...                                          ...     ...
# 4226        4226                       Maruti Swift Dzire ZDI  2015.0
# 4231        4231  Toyota Innova 2.5 G (Diesel) 8 Seater BS IV  2011.0
# 4278        4278                    Honda Amaze S Petrol BSIV  2020.0
# 4292        4292                       Nissan Sunny Diesel XL  2012.0
# 4318        4318                              Maruti Alto STD  2005.0
#
#       selling_price  km_driven  fuel seller_type transmission         owner
# ...

# %%
# Removing the 'none' values of the fuel column..
car_data_2 = car_data_1[car_data_1['fuel'] != 'none']
car_data_2
# Out:
#       Unnamed: 0                                 name    year  selling_price  \
# 0              0                        Maruti 800 AC  2007.0          60000
# 1              1             Maruti Wagon R LXI Minor  2007.0         135000
# 2              2                 Hyundai Verna 1.6 SX  2012.0         600000
# 3              3               Datsun RediGO T Option  2017.0         250000
# 4              4                Honda Amaze VX i-DTEC  2014.0         450000
# ...          ...                                  ...     ...            ...
# 4335        4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0         409999
# 4336        4336           Hyundai i20 Magna 1.4 CRDi  2014.0         409999
# 4337        4337                  Maruti 800 AC BSIII  2009.0         110000
# 4338        4338     Hyundai Creta 1.6 CRDi SX Option  2016.0         865000
# 4339        4339                     Renault KWID RXT  2016.0         225000
#
# ...

# %%
#Displaying the dataframe after finishing cleaning the NaN and none values.
car_data_2
# Out:
#       Unnamed: 0                                 name    year  selling_price  \
# 0              0                        Maruti 800 AC  2007.0          60000
# 1              1             Maruti Wagon R LXI Minor  2007.0         135000
# 2              2                 Hyundai Verna 1.6 SX  2012.0         600000
# 3              3               Datsun RediGO T Option  2017.0         250000
# 4              4                Honda Amaze VX i-DTEC  2014.0         450000
# ...          ...                                  ...     ...            ...
# 4335        4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014.0         409999
# 4336        4336           Hyundai i20 Magna 1.4 CRDi  2014.0         409999
# 4337        4337                  Maruti 800 AC BSIII  2009.0         110000
# 4338        4338     Hyundai Creta 1.6 CRDi SX Option  2016.0         865000
# 4339        4339                     Renault KWID RXT  2016.0         225000
#
# ...

# %%
#Check if the dataset still contains the missing values in any columns.
car_data_2.isnull().sum()
# Out:
# Unnamed: 0       0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#Print the total number of rows after cleaning the data.
print("The length of data after cleaning is :",len(car_data_2))
# Out:
# The length of data after cleaning is : 3886

# %% [markdown]
# ## Q2. Descriptive statistics
#
# With the cleaned data in Q1, please provide the data summarization as below:
#
# * Q2.1 total number of unique name, unique seller_type, unique transmission, and unique owner
# * Q2.2 descriptive statistics, including the total number, mean, std, min and max regarding all km_driven
# * Q2.3 descriptive statistics, including mean, std, max, and min of the number of selling_price grouped by different seller_type
# * Q2.4 descriptive statistics, including mean, std, max, min of the number of years that sold by each owner type

# %%
#Print the number of uniques values in the 'name' , 'seller_type', 'transmission' and 'owner'
print("Q 2.1")

print("1. The number of uniques values in the 'name' attribute is :",len(car_data_2['name'].unique()))

print("2. The number of uniques values in the 'seller_type' attribute is :",len(car_data_2['seller_type'].unique()))

print("3. The number of uniques values in the 'transmission' attribute is :",len(car_data_2['transmission'].unique()))

print("4. The number of uniques values in the 'owner' attribute is :",len(car_data_2['owner'].unique()))
# Out:
# Q 2.1
# 1. The number of uniques values in the 'name' attribute is : 1402
# 2. The number of uniques values in the 'seller_type' attribute is : 3
# 3. The number of uniques values in the 'transmission' attribute is : 2
# 4. The number of uniques values in the 'owner' attribute is : 5

# %%
#Descriptive statistics calculation(Mean, total number, std, min and max):
print("Q 2.2")

print("The total value of km driven is: ", car_data_2['km_driven'].sum())

print("The mean value of the total km's travelled is :", car_data_2['km_driven'].mean())

print("The standard deviation of km driven is: ", car_data_2['km_driven'].std())

print("The maximum value of km driven is: ", car_data_2['km_driven'].max())

print("The minimum value of km driven is: ", car_data_2['km_driven'].min())
# Out:
# Q 2.2
# The total value of km driven is:  257693403
# The mean value of the total km's travelled is : 66313.27920741122
# The standard deviation of km driven is:  46679.603915975706
# The maximum value of km driven is:  806599
# The minimum value of km driven is:  1

# %%
#Finding descriptive statistics of selling_price by unique seller types:
print("Q 2.3")

#Finding the unique values within the column name 'seller_type'
print("The unique seller types are: ", car_data_2['seller_type'].unique())
# Out:
# Q 2.3
# The unique seller types are:  ['Individual' 'Dealer' 'Trustmark Dealer']

# %%
#Creating different dataframes for each types of seller...

individual_seller = car_data_2[car_data_2['seller_type'] == 'Individual']
print("The number of individual sellers are: ", len(individual_seller))

dealer = car_data_2[car_data_2['seller_type'] == "Dealer"]
print("The number of dealers are: ", len(dealer))

trustmark_dealer = car_data_2[car_data_2['seller_type'] == "Trustmark Dealer"]
print("The number of trustmark dealers are: ", len(trustmark_dealer))
# Out:
# The number of individual sellers are:  2903
# The number of dealers are:  889
# The number of trustmark dealers are:  94

# %%
print("\nThe descriptive statistics for the individual seller types, by selling price are: \n")

print("The total value of selling price is: ", individual_seller['selling_price'].sum())

print("The mean value of the selling price is :", individual_seller['selling_price'].mean())

print("The standard deviation of selling price is: ", individual_seller['selling_price'].std())

print("The maximum value of selling price is: ", individual_seller['selling_price'].max())

print("The minimum value of selling price is: ", individual_seller['selling_price'].min())
# Out:
# The descriptive statistics for the individual seller types, by selling price are:
#
# The total value of selling price is:  1222654798
# The mean value of the selling price is : 421169.41026524286
# The standard deviation of selling price is:  420273.68412882165
# The maximum value of selling price is:  4800000
# The minimum value of selling price is:  20000

# %%
print("\nThe descriptive statistics for trustmark dealer types are: \n ")

print("Mean : ", trustmark_dealer['selling_price'].mean())

print("Standard Deviation : ", trustmark_dealer['selling_price'].std())

print("Minimum value : ", trustmark_dealer['selling_price'].min())

print("Maximum Value : ", trustmark_dealer['selling_price'].max())
# Out:
# The descriptive statistics for trustmark dealer types are:
#
# Mean :  935797.8723404255
# Standard Deviation :  655724.29919484
# Minimum value :  315000
# Maximum Value :  2600000

# %%
print("\nThe descriptive statistics for Dealer types are: ")

print("Mean : ", dealer['selling_price'].mean())

print("Standard Deviation : ", dealer['selling_price'].std())

print("Minimum value : ", dealer['selling_price'].min())

print("Maximum Value : ", dealer['selling_price'].max())
# Out:
# The descriptive statistics for Dealer types are:
# Mean :  702093.3149606299
# Standard Deviation :  813597.8118319241
# Minimum value :  22000
# Maximum Value :  8900000

# %%
print("Q 2.4\n")

#Getting the unique values of the owner type...
print(car_data_2['owner'].unique())
# Out:
# Q 2.4
#
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
#Creating different dataframes for each owner type.

first_owner = car_data_2[car_data_2['owner'] == "First Owner"]

second_owner = car_data_2[car_data_2['owner'] == 'Second Owner']

third_owner = car_data_2[car_data_2['owner'] == 'Third Owner']

other_owner = car_data_2[car_data_2['owner'] == 'Fourth & Above Owner']

test_owner = car_data_2[car_data_2['owner'] == 'Test Drive Car']

#Check if all the values are separated into different groups by counting the individual length of the values..
print(len(first_owner) +  len(second_owner) +  len(third_owner) +  len(test_owner) + len(other_owner),  len(car_data_2))
# Out:
# 3886 3886

# %%
print("The descriptive statistics for the unique owner types by year are: \n")

print("First Owner: ")
print("Mean: ", first_owner['year'].mean())
print("Standard Deviation: ", first_owner['year'].std())
print("Minimum Value: ", first_owner['year'].min())
print("Maximum Value: ", first_owner['year'].max())

print("\nSecond Owner: ")
print("\nMean: ", second_owner['year'].mean())
print("Standard Deviation: ", second_owner['year'].std())
print("Minimum Value: ", second_owner['year'].min())
print("Maximum Value: ", second_owner['year'].max())

print("\nOther Owner: ")
print("\nMean: ", other_owner['year'].mean())
print("Standard Deviation: ", other_owner['year'].std())
print("Minimum Value: ", other_owner['year'].min())
print("Maximum Value: ", other_owner['year'].max())

print("\nTest Drive Car Owner: ")
print("\nMean: ", test_owner['year'].mean())
print("Standard Deviation: ", test_owner['year'].std())
print("Minimum Value: ", test_owner['year'].min())
print("Maximum Value: ", test_owner['year'].max())
# Out:
# The descriptive statistics for the unique owner types by year are:
#
# First Owner:
# Mean:  2014.4537914691944
# Standard Deviation:  3.555597453653635
# Minimum Value:  1996.0
# Maximum Value:  2020.0
#
# Second Owner:
#
# Mean:  2010.977
# Standard Deviation:  3.84099260923844
# Minimum Value:  1995.0
# Maximum Value:  2019.0
#
# Other Owner:
#
# Mean:  2007.2388059701493
# Standard Deviation:  5.24863489391868
# Minimum Value:  1992.0
# Maximum Value:  2020.0
#
# Test Drive Car Owner:
#
# Mean:  2019.642857142857
# Standard Deviation:  0.6333236937766509
# Minimum Value:  2018.0
# Maximum Value:  2020.0

# %%
#option 2 for calculating descriptive statistics for the car_owner dataframe
# Using describe to get statistics
description = test_owner.describe()

# Selecting specific statistics (e.g., 'mean', 'std', 'min', 'max')
selected_stats = description.loc[['mean', 'std', 'min', 'max']]

# Renaming the 'Unnamed: 0' column to something more meaningful, e.g., 'Index'
selected_stats = selected_stats.rename(columns={'Unnamed: 0': 'Values'})

# Display the selected statistics
print(selected_stats.Values)
# Out:
# mean    1979.714286
# std      518.561832
# min     1714.000000
# max     3615.000000
# Name: Values, dtype: float64

# %% [markdown]
# ## Q3. Plotting and Analysis
#
# Please try to explore the correlation between fuel/year/seller_type/transmission/owner and selling_price; for instance, do First Owner cars tend to sell higher prices than second owner cars? Hint: you may use the boxplot function to plot figures for comparison
#
# You may need to select the most suitable graphic forms for ease of presentation. Most importantly, for each figure or subfigure, please summarise ___what each plot shows___ (i.e. observations and explanations). Finally, you are required to provide an overall summary of your findings from the plots you generated.

# %%
#Import the data and create box plot based on the relation between selling prce and owner...
#Using Seaborn Library to create the plot
plt.figure(figsize = (12,6))
sns.boxplot(x = "owner", y = "selling_price", data = car_data_2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.title('Selling Price by Owner Type')
plt.xlabel('Owner Type')
plt.ylabel('Selling Price')
plt.show()

# Option using matplotlib for the same diagram
#Import the data and create box plot based on the relation between selling prce and owner...
# car_data_2.boxplot(column='selling_price', by='owner', grid=False)
# plt.title('Selling Price by Owner Type')
# plt.suptitle('')  # Suppress the default title to avoid duplication
# plt.xlabel('Owner Type')
# plt.ylabel('Selling Price')
# plt.ticklabel_format(style='plain', axis='y')
# plt.show()

# %% [markdown]
# # Anaysis (Selling Price by Owner Type):
# ### The plot shows the distribution of selling prices for different owner types. First-owner cars often have higher median prices.

# %%
#Import the data and create box plot based on the relation between selling prce and Transmission...
#Using Seaborn Library to create the plot
plt.figure(figsize = (12,6))
sns.boxplot(x = "transmission", y = "selling_price", data = car_data_2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.title('Selling Price by Owner Type')
plt.xlabel('Transmission')
plt.ylabel('Selling Price')
plt.show()


#option 2
# car_data_2.boxplot(column='selling_price', by='transmission', grid=False)
# plt.title('Selling Price by Transmission')
# plt.suptitle('')  # Suppress the default title to avoid duplication
# plt.xlabel('Transmission')
# plt.ylabel('Selling Price')
# plt.show()

# %% [markdown]
# ## Analysis of Selling price by Transmission
# ### This plot shows that automatic cars generally have higher selling prices.

# %%
#Using Seaborn Library to create the plot for selling price by fuel
plt.figure(figsize = (12,6))
sns.boxplot(x = "fuel", y = "selling_price", data = car_data_2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.title('Selling Price by Owner Type')
plt.xlabel('Fuel')
plt.ylabel('Selling Price')
plt.show()


#option 2
# car_data_2.boxplot(column='selling_price', by='fuel', grid=False)
# plt.title('Selling Price by Fuel')
# plt.suptitle('')  # Suppress the default title to avoid duplication
# plt.xlabel('Fuel')
# plt.ylabel('Selling Price')
# plt.show()

# %% [markdown]
# ## Anaysis (Selling Price by Fuel):
# ### The plot shows the distribution of selling prices for. Hybrid cars might show higher prices due to their efficiency benefits.

# %%
#Using Seaborn Library to create the plot for selling price by year
plt.figure(figsize = (12,6))
sns.boxplot(x = "year", y = "selling_price", data = car_data_2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.title('Selling Price by Owner Type')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.show()


# Option 2
# car_data_2.boxplot(column='selling_price', by='year', grid=False)
# plt.title('Selling Price by Year')
# plt.suptitle('')  # Suppress the default title to avoid duplication
# plt.xlabel('Owner Type')
# plt.ylabel('Selling Price')
# plt.show()

# %% [markdown]
# ## Analysis of Selling price by Year
# ### Newer cars tend to have higher selling prices, reflecting their newer technology and lower mileage.

# %%
#Using Seaborn Library to create the plot for selling price by fuel
plt.figure(figsize = (12,6))
sns.boxplot(x = "seller_type", y = "selling_price", data = car_data_2)
plt.gca().get_yaxis().get_major_formatter().set_scientific(False)
plt.title('Selling Price by Owner Type')
plt.xlabel('Seller Type')
plt.ylabel('Selling Price')
plt.show()

# Option 2
# car_data_2.boxplot(column='selling_price', by='seller_type', grid=False)
# plt.title('Selling Price by Seller Type')
# plt.suptitle('')  # Suppress the default title to avoid duplication
# plt.xlabel('Seller Type')
# plt.ylabel('Selling Price')
# plt.show()

# %% [markdown]
# ## Analysis (Selling Price by Seller Type)
# ### Hybrid cars might show higher prices due to their efficiency benefits.

# %% [markdown]
# ## Q4. Detect and remove outliers
#
# We define car sale records WITHOUT following ANY of the below three rules as outliers:
#
# 1. owner to be first, second and third owner only
# 2. Fuel to be Diesel or Petrol only
# 3. Seller_type to be dealer or individual only
#
# Please remove the corresponding records in the csv file that is not qualified with the rules. After that, __print the length of the data__.

# %%
# Define the criteria for valid records
valid_owners = ['First Owner', 'Second Owner', 'Third Owner']
valid_fuels = ['Diesel', 'Petrol']
valid_seller_types = ['Dealer', 'Individual']

# Filter the DataFrame based on the criteria
filtered_data = car_data_2[
    (car_data_2['owner'].isin(valid_owners)) &
    (car_data_2['fuel'].isin(valid_fuels)) &
    (car_data_2['seller_type'].isin(valid_seller_types))
]

# Print the length of the filtered data
print("Number of valid records:", len(filtered_data))
# Out:
# Number of valid records: 3657
